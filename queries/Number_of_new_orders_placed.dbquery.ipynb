-- %%
SELECT  
count(*) AS new_orders_placed, 
order_version AS of_version, 
order_date as on_date
FROM case_study_de.order_bronze 
WHERE order_status = 'placed'
AND order_date = DATE '2025-05-15' OR order_date = DATE '2025-05-16'
GROUP BY order_version, order_date;
