-- %%
SELECT * FROM case_study_de.customer_bronze
WHERE 
(first_name IS NULL OR 
last_name IS NULL OR 
phone IS NULL OR 
country IS NULL OR 
email_id IS NULL) OR 
(phone NOT RLIKE '^\\+?[0-9\\s\\-()]{6,20}$') OR
(email_id NOT RLIKE '^[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\\.[A-Za-z]{2,}$') 
OR (first_name NOT RLIKE '^[\\p{L}]+([\\''-][\\p{L}]+)*$')
OR (last_name NOT RLIKE '^[\\p{L}]+([\\''-][\\p{L}]+)*$')
