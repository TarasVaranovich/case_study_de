-- %%
CREATE TABLE IF NOT EXISTS case_study_de.customer_bronze (
  customer_nk VARCHAR(24),
  first_name VARCHAR(300),
  last_name VARCHAR(300),
  phone VARCHAR (20),
  country VARCHAR(60),
  email_id VARCHAR(320),
  custmer_nk_num LONG,
  customer_version SMALLINT
);
CREATE TABLE IF NOT EXISTS case_study_de.order_bronze (
  order_nk VARCHAR(23),
  oreder_timestamp TIMESTAMP,
  product_nk VARCHAR(23),
  customer_nk VARCHAR(24),
  revenue DECIMAL(10,2),
  order_status VARCHAR(10),
  order_nk_num LONG,
  order_version SMALLINT,
  customer_nk_num LONG,
  customer_version SMALLINT,
  product_nk_num LONG,
  product_version SMALLINT
);
